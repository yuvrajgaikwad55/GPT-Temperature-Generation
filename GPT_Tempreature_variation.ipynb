# %%
# !pip install -q transformers torch

# %%
from transformers import pipeline
import torch

# %%
generator = pipeline(
    "text-generation",
    model="distilgpt2",
    device=0 if torch.cuda.is_available() else -1
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  353MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
prompt = "Explain Artificial Intelligence in about 50 words."

temperatures = [0.2, 0.5, 0.8, 1.0, 1.2]

for temp in temperatures:
    print("=" * 70)
    print(f"Temperature = {temp}")
    print("=" * 70)

    output = generator(
        prompt,
        max_new_tokens=60,
        temperature=temp,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        num_return_sequences=1
    )

    print(output[0]["generated_text"])
    print("\n")
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'top_p', 'max_new_tokens', 'top_k', 'do_sample', 'num_return_sequences', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ======================================================================
# Temperature = 0.2
# ======================================================================
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Artificial Intelligence in about 50 words.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ======================================================================
# Temperature = 0.5
# ======================================================================
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Artificial Intelligence in about 50 words.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ======================================================================
# Temperature = 0.8
# ======================================================================
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Artificial Intelligence in about 50 words.
#
#
# The research team of MIT and Stanford researchers led by Dr. T.J. R. Hall of the National Institute of Standards and Technology (NIST) and Prof. Y. C. Hall of the National Institute of Standards and Technology (NIST) also examined several different topics related
#
#
# ======================================================================
# Temperature = 1.0
# ======================================================================
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Explain Artificial Intelligence in about 50 words. It seems to me that AI is about 20 to 30 seconds faster than we need it to be. I'm only hearing that from people, but I do believe that by understanding people who have made their own predictions that AI is about 90 percent more accurate than we need it to be in some form.
#
#
# ======================================================================
# Temperature = 1.2
# ======================================================================
# Explain Artificial Intelligence in about 50 words.
#
# A word which is used is a term in English and in an English word such as e (› ɼ ṃ ɛ ɕ ɹ ˌ t ), followed by e (› ɑ ɑ ɑ �
